# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig=plt.figure(dpi= 120, facecolor='w', edgecolor='k')
#### read in the txt file
import numpy as np
raw_data = np.loadtxt('../data/joints_data.txt', delimiter=',')

plt.plot(raw_data[:,1:])
plt.xlabel("Index")
plt.ylabel("Joint Angle (radians)")
# Out:
# Text(0,0.5,'Joint Angle (radians)')

# %%
fig=plt.figure(dpi= 120, facecolor='w', edgecolor='k')
raw_data = np.loadtxt('../data/ur5_translated_pose_data_truncated.txt', delimiter=',')

plt.plot(raw_data[:,1:4])
plt.xlabel("Index")
plt.ylabel("Position (m)")
raw_data.shape
# Out:
# (325, 8)
