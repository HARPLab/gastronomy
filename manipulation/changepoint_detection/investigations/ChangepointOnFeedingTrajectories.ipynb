# %%
# %matplotlib inline

# %%
# now, read in the newly created txt file and model it and plot the resulting model
import numpy as np
from statsmodels.nonparametric.smoothers_lowess import lowess
all_data = np.loadtxt('../data/pose_data_full_sample.txt', delimiter=',')
# see https://hmmlearn.readthedocs.io/en/latest/tutorial.html

# smooth the data
raw_z_data = all_data[:,1:4]
plt.plot(raw_z_data)
# Out:
# [<matplotlib.lines.Line2D at 0x7feda1318ef0>,
#  <matplotlib.lines.Line2D at 0x7feda13184e0>,
#  <matplotlib.lines.Line2D at 0x7feda1318048>]

# %%
import matplotlib.pyplot as plt
plt.plot(z_data)
sample_z_data
# Out:
# array([[0.96369525]])

# %%
0:z_data_size//num_samples:z_data_size
# Out:
#   File "<ipython-input-11-53d20468ca78>", line 1
#     0:z_data_size//num_samples:z_data_size
#      ^
# SyntaxError: invalid syntax
